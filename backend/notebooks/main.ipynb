# %% [markdown]
# 1. this is the first attempt to copy this so called sapujagad and make it my own named "sapusugi" mk II Pak RERE

# %%
# nama = "Agoes"
# print("Nama:"  nama)



# ===== SUGGESTION =====
# # correct code
nama = "Agoes"
print(f"Nama:{nama}")
# ======================
# Out:
# Nama:Agoes

# %%
import math

# Calculate the square root of 64
result = math.sqrt(120)
print(result)
# Out:
# 10.954451150103322

# %%
# ===== SUGGESTION =====
# This means that your code is trying to use the built-in function `input()` for taking user input, which is a feature available in some environments like Jupyter Notebooks or interactive consoles. However, it seems you are using an environment where `raw_input()` (used in older versions of Python) has been deprecated and replaced by other methods for handling inputs.
# 
# In modern Python environments, the recommended way to take user input is through built-in functions such as `input()`, `sys.stdin.read()` or `getpass.getpass()` depending on your requirements. If you're using an environment that doesn't support `raw_input()`, here are some solutions:
# 
# ### Solution 1: Use Built-In Functions
# You can use built-in functions like `input()` to get user input:
# ```python
# num1 = float(input("Enter first number: "))
# num2 = float(input("Enter second number: "))
# ```
# 
# ### Solution 2: Replace `raw_input()` with other methods if available in your environment.
# Check if you can replace `input()` or `sys.stdin.read()` with other built-in functions. For example, `getpass.getpass()` might be an option depending on the environment.
# 
# ### Solution 3: Consider Upgrading Python
# If possible, consider upgrading to a more recent version of Python which typically has better support for handling user input across different environments.
# 
# Here's how you can fix your code based on the first solution:
# ```python
# Simple Calculator in Python

# Get user input
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

# Calculate
result_add = num1 + num2
result_sub = num1 - num2

# Display results
print("Result: Add =", result_add)
print("Result: Subtract =", result_sub)
# ```
# 
# This should work in most modern Python environments without needing to replace `input()` or use other deprecated methods.
# ======================
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# Cell In[3], line 24
#       1 # ===== SUGGESTION =====
#       2 # This means that your code is trying to use the built-in function `input()` for taking user input, which is a feature available in some environments like Jupyter Notebooks or interactive consoles. However, it seems you are using an environment where `raw_input()` (used in older versions of Python) has been deprecated and replaced by other methods for handling inputs.
#       3 #
#    (...)     22
#      23 # Get user input
# ---> 24 num1 = float(input("Enter first number: "))
#      25 num2 = float(input("Enter second number: "))
#      27 # Calculate
#
# File D:\HDD_Documents\Python\intel-arc-ollama\sapusugi\backend\.venv\Lib\site-packages\ipykernel\kernelbase.py:1395, in Kernel.raw_input(self, prompt)
#    1393 if not self._allow_stdin:
# ...
